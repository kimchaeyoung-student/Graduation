# %% [markdown]
# <a href="https://colab.research.google.com/github/kimchaeyoung-student/Graduation/blob/main/DentalCare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#드라이브에 접근할 수 있도록 아래 코드 입력
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#불러올 파일의 경로를 filename 변수에 저장
filename = '/content/drive/My Drive/hospital.csv'
filename2 = '/content/drive/My Drive/subway.csv'

# %%
import pandas as pd

# %%
#pandas read_csv로 불러오기
data = pd.read_csv(filename)
data.head()
# Out:
#    번호 개방서비스명     개방서비스id  개방자치단체코드  ... 총인원  구조사수  허가병상수  최초지정일자
# 0   1     병원  01_01_01_P   6460000  ... NaN   NaN    0.0     NaN
# 1   2     병원  01_01_01_P   3120000  ... NaN   NaN    0.0     NaN
# 2   3     병원  01_01_01_P   3190000  ... NaN   NaN    0.0     NaN
# 3   4     병원  01_01_01_P   4020000  ... NaN   NaN    0.0     NaN
# 4   5     병원  01_01_01_P   4010000  ... NaN   NaN    0.0     NaN
#
# [5 rows x 44 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6507 entries, 0 to 6506
# Data columns (total 44 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   번호         6507 non-null   int64
#  1   개방서비스명     6507 non-null   object
#  2   개방서비스id    6507 non-null   object
#  3   개방자치단체코드   6507 non-null   int64
#  4   관리번호       6507 non-null   object
#  5   인허가일자      6507 non-null   int64
#  6   인허가취소일자    1 non-null      float64
#  7   영업상태구분코드   6507 non-null   int64
#  8   영업상태명      6507 non-null   object
#  9   상세영업상태코드   6507 non-null   object
#  10  상세영업상태명    6506 non-null   object
#  11  폐업일자       2011 non-null   float64
#  12  휴업시작일자     239 non-null    float64
#  13  휴업종료일자     235 non-null    float64
#  14  재개업일자      0 non-null      float64
#  15  소재지전화      6243 non-null   object
#  16  소재지면적      0 non-null      float64
#  17  소재지우편번호    2874 non-null   object
#  18  소재지전체주소    5287 non-null   object
# ...

# %%
dental = data[data["업태구분명"]=="치과병원"]

# %%
# Save iot data in csv file.
dental.to_csv('dental.csv')

# %%
import folium
from pandas import DataFrame   # 데이터 분석 패키지
from pandas import ExcelFile

# %%
dentalfile = '/content/dental.csv'  # 치과병원만 뽑아낸 파일

# %%
d = pd.read_csv(dentalfile)
d.head()
# Out:
#    Unnamed: 0   번호 개방서비스명     개방서비스id  ...  총인원 구조사수  허가병상수  최초지정일자
# 0          12   13     병원  01_01_01_P  ...  NaN  NaN    0.0     NaN
# 1          96   97     병원  01_01_01_P  ...  NaN  NaN    0.0     NaN
# 2          97   98     병원  01_01_01_P  ...  NaN  NaN    0.0     NaN
# 3         107  108     병원  01_01_01_P  ...  NaN  NaN    0.0     NaN
# 4         117  118     병원  01_01_01_P  ...  NaN  NaN    0.0     NaN
#
# [5 rows x 45 columns]

# %%
df = dental.filter(['사업장명''업태구분명','도로명전체주소','좌표정보(x)','좌표정보(y)'])
df
# Out:
#                     사업장명 업태구분명  ...      좌표정보(x)      좌표정보(y)
# 12                을지치과병원  치과병원  ...  199213.9958  451479.2513
# 96               참조은치과병원  치과병원  ...  192429.1403  455926.6494
# 97                성가치과병원  치과병원  ...  192443.7067  456716.7031
# 107               한양치과병원  치과병원  ...  194251.3636  455531.0132
# 117               송파치과병원  치과병원  ...  208426.1691  444447.6822
# ...                  ...   ...  ...          ...          ...
# 6367           서울귀한이치과병원  치과병원  ...  200800.4170  444989.8743
# 6370               필치과병원  치과병원  ...  198946.3256  443620.4529
# 6376             서울탑치과병원  치과병원  ...  201322.3049  442566.6411
# 6426            에이라인치과병원  치과병원  ...  238290.8572  347204.2411
# 6474  의료법인 이손의료재단 이손치과병원  치과병원  ...  167065.3569  377371.4508
#
# [337 rows x 5 columns]

# %%
df2 = df['도로명전체주소'].str.contains('서울특별시')
df2
# Out:
# 12       True
# 96       True
# 97       True
# 107      True
# 117      True
#         ...
# 6367     True
# 6370     True
# 6376     True
# 6426    False
# 6474    False
# Name: 도로명전체주소, Length: 337, dtype: object

# %%
for i in df2.index:
  lat = df2.loc[i,'좌표정보(x)']
  lng = df2.loc[i,'좌표정보(y)']

  marker = folium.Marker([lat,lng], popup=name)
  marker.add_to(map_osm)

map_osm.save('서울의_치과병원분포.html')
map_osm

# %% [markdown]
# -----

# %%
subway = pd.read_csv(filename2)

# %%
subway
# Out:
#          지하철역명         위도          경도
# 0         가락시장  37.492522  127.118234
# 1         종로3가  37.571607  126.991806
# 2           오금  37.502162  127.128111
# 3          동대문  37.571420  127.009745
# 4    동대문역사문화공원  37.565138  127.007896
# ..         ...        ...         ...
# 584         동백  37.269043  127.152716
# 585         초당  37.260752  127.159443
# 586         삼가  37.242115  127.168075
# 587     시청·용인대  37.239151  127.178406
# 588        명지대  37.237964  127.190294
#
# [589 rows x 3 columns]

# %%
map_osm = folium.Map(location=[37.566647,126.978426], zoom_start=10, tiles='Stamen Terrain')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for i in df3.index:
    # 행 우선 접근 방식으로 값 추출하기
    name = df3.loc[i, '지하철역명']
    lat = df3.loc[i, '위도']
    lng = df3.loc[i, '경도']
    
    # 추출한 정보를 지도에 표시
    marker = folium.Marker([lat,lng], popup=name)
    marker.add_to(map_osm)

map_osm.save('서울의_지하철역_분포.html')
map_osm
